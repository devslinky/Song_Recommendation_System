# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/Analytics Project/Playlist Datasets to Train ML model/new_school_rap.csv')
df = df[df['in_playlist'] == 1]
df.drop(['popularity', 'track_id', 'uri', 'danceability', 'energy', 'key', 'loudness', 'valence', 'tempo', 'type', 'id', 'track_href', 'analysis_url', 'duration_ms', 'time_signature', 'release_date', 'in_playlist', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness'], axis = 1)
# Out:
#                                  track_name  \
# 2                    Swimming Pools (Drank)
# 9                                 TELESCOPE
# 10                     EA (feat. 21 Savage)
# 12   #CERTIFIED (feat. DJ Ess) - DJ Ess Mix
# 15                                   BANDIT
# ..                                      ...
# 171                            I Don't Like
# 175                             pop ur shit
# 179                                 Camelot
# 180                                    Yale
# 182                                 UKRAINE
#
#                                      artist_name  \
# 2                             ['Kendrick Lamar']
# 9                 ['TWXN', 'LL Clawz', '507KAZ']
# 10                   ['Young Nudy', '21 Savage']
# 12                        ['BabyTron', 'DJ Ess']
# 15                               ['Don Toliver']
# ..                                           ...
# 171                  ['Chief Keef', 'Lil Reese']
# ...
